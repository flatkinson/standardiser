# %%
# %run notebook_setup.py

sys.path.append('../..')

# %%
from standardiser import standardise

# %%
standardise.logger.setLevel('DEBUG')

# %% [markdown]
# # `standardise`: get standardised parent

# %% [markdown]
# ### Introduction
#
# This document provides some examples of the use of the **`standardise`** module, which uses the component modules described in the previous documents.

# %% [markdown]
# ### Examples

# %%
mol = Chem.MolFromSmiles("[Na]OC(=O)Cc1ccc(C[NH3+])cc1.c1nnn[n-]1.O")

mol

# %%
parent = None

try:
    
    parent = standardise.apply(mol)
    
except standardise.StandardiseException as e:
    
    logging.warn(e.message)
    
parent
# Out:
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 1 '[Na+]'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 2 '[NH3+]Cc1ccc(CC(=O)[O-])cc1'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 DEBUG   ] ...fragment kept.
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 3 'c1nnn[n-]1'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 4 'O'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...

# %% [markdown]
# ### Multiple non-salt/solvate components

# %%
mol = Chem.MolFromSmiles("[Na]OC(=O)Cc1ccc(C[NH3+])cc1.Cc1nnn[n-]1.O")

mol

# %%
parent = None

try:
    
    parent = standardise.apply(mol)
    
except standardise.StandardiseException as e:
    
    logging.warning(e.message)
    
parent
# Out:
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 1 '[Na+]'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 2 '[NH3+]Cc1ccc(CC(=O)[O-])cc1'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 DEBUG   ] ...fragment kept.
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 3 'Cc1nnn[n-]1'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 DEBUG   ] ...fragment kept.
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 4 'O'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 WARNING ] Multiple non-salt/solvate components

# %% [markdown]
# ### No non-salt/solvate components

# %%
mol = Chem.MolFromSmiles("c1nnn[n-]1.O")

mol

# %%
parent = None

try:
    
    parent = standardise.apply(mol)
    
except standardise.StandardiseException as e:
    
    logging.warning(e.message)
    
parent
# Out:
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 1 'c1nnn[n-]1'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 DEBUG   ] Starting fragment 2 'O'...
# [2016/Mar/24 16:16:25 DEBUG   ] 1) Check for non-organic elements...
# [2016/Mar/24 16:16:25 DEBUG   ] 2) Attempting to neutralise (first pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 3) Applying rules...
# [2016/Mar/24 16:16:25 DEBUG   ] 4) Attempting to neutralise (second pass)...
# [2016/Mar/24 16:16:25 DEBUG   ] 5) Checking if frag is a salt/solvate...
# [2016/Mar/24 16:16:25 WARNING ] No non-salt/solvate components

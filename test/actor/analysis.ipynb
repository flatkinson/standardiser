# %%
# %run setup.py

sys.path.append("../..")

from standardise import rules

# %% [markdown]
# ## Check the bahaviour of the standardiser rules by running on some ACToR structures

# %%
# Load standardised structures (NB import all columns as strings)...

cols = ['smiles_new', 'name', 'smiles_old', 'rules_applied']

rules_applied = pd.read_table(open('rules_applied.smi', 'r'), header=None, names=cols, dtype={x: np.str for x in cols})

rules_applied.set_index('name', inplace=True)

len(rules_applied)
# Out:
# 5987

# %%
# Add molecule columns to data frame...

PandasTools.AddMoleculeColumnToFrame(rules_applied, smilesCol='smiles_old', molCol='mol_old')
PandasTools.AddMoleculeColumnToFrame(rules_applied, smilesCol='smiles_new', molCol='mol_new')
del rules_applied["smiles_old"], rules_applied["smiles_new"]

rules_applied["rules_applied"] = rules_applied["rules_applied"].apply(lambda x: [int(x) for x in x.split(",")])
# Out:
# Patching pandas
# Patching pandas

# %%
# Molecules having multiple rules applied...

multi = rules_applied.ix[[i for i, x in enumerate(rules_applied['rules_applied']) if len(x) > 1], :]

multi
# Out:
#             rules_applied                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 19807-96-6        [5, 28]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 142181-44-0       [5, 28]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 97151-31-0        [5, 28]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 13389-07-6         [5, 7]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 7467-38-1         [3, 27]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>
# 149478-71-7       [5, 28]  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>
# 13421-41-5         [5, 7]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>
# 3977-29-5          [2, 6]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>

# %%
# Split dataframe into one per rule...

frames = {n: rules_applied[rules_applied["rules_applied"].apply(lambda x: n in x)] for n in (x["n"] for x in rules.rule_set)}

names = {x["n"]: x["name"] for x in rules.rule_set}

for n, frame in frames.items(): print("{:2d}) {:50s}: {:3d}".format(n, names[n], frame.shape[0]))
# Out:
#  1) hydroxy imine -> carboxamide                      : 158
#  2) 2-hydroxy pyridine -> 2-pyridone                  : 353
#  3) 4-hydroxy pyridine -> 4-pyridone (within-ring)    : 221
#  4) 4-hydroxy pyridine -> 4-pyridone (any)            : 109
#  5) 4-pyrimidone -> 2-pyrimidone (any)                : 2537
#  6) hydropyridin-2-imine -> 2-amino-pyridine          :  25
#  7) hydropyridin-2-imine -> 2-amino-pyridine (N-subst.): 384
#  8) hydropyridin-4-imine -> 4-amino-pyridine          :  16
#  9) hydropyridin-4-imine -> 4-amino-pyridine (N-subst.):  70
# 10) Fix heterocyclic tautomer 1                       :  19
# 11) Fix heterocyclic tautomer 2                       :  10
# 12) Fix heterocyclic tautomer 3                       :  17
# 13) Fix heterocyclic tautomer 4                       :   0
# 14) Enol -> Ketone                                    :   0
# 15) Fix 1,3 charge-seperated systems (non-aromatic)   :   0
# 16) Fix 1,3 charge-seperated systems (aromatic 1)     :   0
# 17) Fix 1,3 charge-seperated systems (aromatic 2)     :   1
# 18) Fix 1,5 charge-seperated systems (non-aromatic)   :   0
# 19) Fix 1,5 charge-seperated systems (aromatic 1)     :   0
# 20) Fix 1,5 charge-seperated systems (aromatic 2)     :   1
# 21) Fix 1,3 conjugated cation (non-aromatic)          :  33
# 22) Fix 1,3 conjugated cation (aromatic 1)            :   1
# 23) Fix 1,3 conjugated cation (aromatic 2)            :  66
# 24) Fix 1,5 conjugated cation (non-aromatic)          :  51
# 25) Fix 1,5 conjugated cation (aromatic 1)            :   0
# 26) Fix 1,5 conjugated cation (aromatic 2)            : 433
# 27) Fix 1,5 conjugated cation (aromatic 3)            :  11
# 28) Charge-seperate sulphoxides                       : 1479
# 29) Un-charge-seperate sulphones                      :   0
# 30) Fix hydrazine-diazonium system                    :   0

# %%
# Inspect a frame...

n = 10 

frames[n].head()
# Out:
#            rules_applied                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        mol_old                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 22724-43-2          [10]  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>
# 53493-62-2          [10]                                              <img src="data:image/png;base64,..." alt="Mol"/>                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 249-06-9            [10]                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>
# 57743-37-0          [10]                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>                      <img src="data:image/png;base64,..." alt="Mol"/>
# 98198-24-4          [10]                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>
